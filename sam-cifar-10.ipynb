# %%
# !git clone https://github.com/sayakpaul/Sharpness-Aware-Minimization-TensorFlow

import sys
import matplotlib.pyplot as plt 
import tensorflow as tf
# Out:
# Cloning into 'Sharpness-Aware-Minimization-TensorFlow'...
# remote: Enumerating objects: 73, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 73 (delta 32), reused 23 (delta 4), pack-reused 0
# Unpacking objects: 100% (73/73), 157.38 KiB | 229.00 KiB/s, done.
# 2024-08-07 14:56:14.097065: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-07 14:56:14.097264: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-07 14:56:14.253150: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# # Prepare Data

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

print(f"Training samples: {len(x_train)}")
print(f"Testing samples: {len(x_test)}")

batch_size = 128
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 11s 0us/step
# Training samples: 50000
# Testing samples: 10000

# %%
# Chuyen doi du lieu hinh anh
def scale(image, label):
    image = tf.image.convert_image_dtype(image, tf.float32)
    label = tf.cast(label, tf.int32)
    return image, label


# Tang cuong du lieu
def augment(image, label):
    image = tf.image.random_crop(image, size = [32, 32, 3])        # Cắt ngẫu nhiên trở lại 32x32
    image = tf.image.random_brightness(image, max_delta = 0.5)     # Độ sáng ngẫu nhiên
    image = tf.clip_by_value(image, 0., 1.)                        # Giới hạn pixel thuộc [0, 1]
    return image, label


# Thiet lap du lieu training
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dataset = (
    train_dataset.shuffle(1024).map(scale)
    .map(augment).batch(batch_size)
)


# Thiet lap du lieu test
test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))
test_dataset = (
    test_dataset.map(scale).batch(batch_size)
)

# %% [markdown]
# # Initialize Model

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras import layers, models

# %%
class SAM(tf.keras.Model):
    def __init__(self, Resnet50, rho = 0.05):
        # Override
        super(SAM, self).__init__()
        self.Resnet50 = Resnet50
        self.rho = rho
        
    def call(self, inputs, training=False):
        return self.Resnet50(inputs, training=training)
    
    def train(self, data):
        (images, labels) = data
        with tf.GradientTape() as tape:
            predictions = self.Resnet50(images)
            loss = self.compiled_loss(labels, predictions)   # Sẽ thiết lập loss ở sau đó
        
        # Tinh e(w) voi p = 2
        e_w = []
        train_params = self.Resnet50.trainable_variables
        grad = tape.gradient(loss, train_params)
        grad_norm = self.grad_norm(grad_norm)                 # Độ lớn của gradient
        scale = self.rho / (grad_norm + 1e-12)
        
        for(grad, param) in zip(grad, train_params):
            g = grad * scale
            param.assign_add(g)
            e_w.append(g)
        
        with tf.GradientTape() as tape:
            predictions = self.Resnet50(images)
            loss = self.compiled(labels, predictions)
        
        sam_grad = tape.gradient(loss, train_params)
        
        # Khoi phuc lai tham so
        for (g, param) in zip(e_w, train_params):
            param.assind_sub(g)
        
        self.optimizer.apply_gradients(zip(sam_grad, train_params))
        
        # Cap nhat phan tu trong metrics
        self.compiled_metrics.update_state(labels, predictions)
        return {m.name: m.result() for m in self.metrics}
    
    def test(self, data):
        (images, labels) = data
        predictions = self.Resnet50(images, training = False)
        loss = self.compiled_loss(labels, predictions)
        self.compiled_metrics.update_state(labels, predictions)
        return {m.name: m.result() for m in self.metrics}
    
    
    # Tinh do lon cua gradient cua tat ca grad khac 0
    def grad_norm(self, grad):
        norm = tf.norm(
            tf.stack([tf.norm(g) for g in grad if g is not None])
        )
        return norm

# %% [markdown]
# # Training Model with SAM

# %%
def get_training_model():
    # Sử dụng ResNet50, bỏ lớp cuối cùng và thêm lớp mới cho CIFAR-10
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(32, 32, 3))
    
    # Đóng băng các tầng của ResNet50
    base_model.trainable = False
    
    # Xây dựng mô hình với lớp phân loại cho CIFAR-10
    model = models.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dense(512, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    
    return model

# %%
model = SAM(get_training_model())
model.compile(
    optimizer = "adam",
    loss = "sparse_categorical_crossentropy",
    metrics = ["accuracy"]
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
import time 
start = time.time()
history = model.fit(train_dataset,
                    validation_data = test_dataset,
                   epochs = 50)
print("Total training time", time.time() - start, "s")
# Out:
# Epoch 1/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 113s 265ms/step - accuracy: 0.1736 - loss: 2.3301 - val_accuracy: 0.3177 - val_loss: 1.9241
# Epoch 2/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 101s 259ms/step - accuracy: 0.2706 - loss: 1.9982 - val_accuracy: 0.2834 - val_loss: 1.9604
# Epoch 3/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 101s 259ms/step - accuracy: 0.2946 - loss: 1.9365 - val_accuracy: 0.3352 - val_loss: 1.8320
# Epoch 4/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 140s 255ms/step - accuracy: 0.3127 - loss: 1.9003 - val_accuracy: 0.3505 - val_loss: 1.7940
# Epoch 5/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 100s 255ms/step - accuracy: 0.3253 - loss: 1.8720 - val_accuracy: 0.3206 - val_loss: 1.9160
# Epoch 6/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 143s 258ms/step - accuracy: 0.3308 - loss: 1.8486 - val_accuracy: 0.3697 - val_loss: 1.7516
# Epoch 7/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 141s 256ms/step - accuracy: 0.3384 - loss: 1.8360 - val_accuracy: 0.3651 - val_loss: 1.7499
# Epoch 8/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 100s 256ms/step - accuracy: 0.3364 - loss: 1.8282 - val_accuracy: 0.3788 - val_loss: 1.7230
# Epoch 9/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 143s 258ms/step - accuracy: 0.3563 - loss: 1.8001 - val_accuracy: 0.3782 - val_loss: 1.7320
# Epoch 10/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 100s 256ms/step - accuracy: 0.3555 - loss: 1.7910 - val_accuracy: 0.3631 - val_loss: 1.7742
# Epoch 11/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 143s 259ms/step - accuracy: 0.3535 - loss: 1.7889 - val_accuracy: 0.3771 - val_loss: 1.7332
# Epoch 12/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 100s 256ms/step - accuracy: 0.3580 - loss: 1.7772 - val_accuracy: 0.3766 - val_loss: 1.7497
# Epoch 13/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 142s 257ms/step - accuracy: 0.3617 - loss: 1.7776 - val_accuracy: 0.3947 - val_loss: 1.6952
# Epoch 14/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 142s 259ms/step - accuracy: 0.3697 - loss: 1.7547 - val_accuracy: 0.3803 - val_loss: 1.7181
# Epoch 15/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 101s 258ms/step - accuracy: 0.3687 - loss: 1.7606 - val_accuracy: 0.3669 - val_loss: 1.7778
# Epoch 16/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 143s 261ms/step - accuracy: 0.3689 - loss: 1.7518 - val_accuracy: 0.3903 - val_loss: 1.6894
# Epoch 17/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 103s 263ms/step - accuracy: 0.3673 - loss: 1.7582 - val_accuracy: 0.3853 - val_loss: 1.7128
# Epoch 18/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 103s 263ms/step - accuracy: 0.3693 - loss: 1.7567 - val_accuracy: 0.3997 - val_loss: 1.6881
# Epoch 19/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 105s 269ms/step - accuracy: 0.3767 - loss: 1.7344 - val_accuracy: 0.3817 - val_loss: 1.7224
# Epoch 20/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 103s 265ms/step - accuracy: 0.3734 - loss: 1.7456 - val_accuracy: 0.4059 - val_loss: 1.6578
# Epoch 21/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 103s 262ms/step - accuracy: 0.3766 - loss: 1.7383 - val_accuracy: 0.3951 - val_loss: 1.6838
# Epoch 22/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 103s 263ms/step - accuracy: 0.3771 - loss: 1.7246 - val_accuracy: 0.3997 - val_loss: 1.6907
# Epoch 23/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 103s 264ms/step - accuracy: 0.3830 - loss: 1.7246 - val_accuracy: 0.3827 - val_loss: 1.7279
# Epoch 24/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 102s 262ms/step - accuracy: 0.3790 - loss: 1.7225 - val_accuracy: 0.3932 - val_loss: 1.6957
# Epoch 25/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 102s 259ms/step - accuracy: 0.3842 - loss: 1.7221 - val_accuracy: 0.4127 - val_loss: 1.6402
# Epoch 26/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 142s 259ms/step - accuracy: 0.3817 - loss: 1.7148 - val_accuracy: 0.3868 - val_loss: 1.6891
# Epoch 27/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 101s 258ms/step - accuracy: 0.3877 - loss: 1.7135 - val_accuracy: 0.4149 - val_loss: 1.6393
# Epoch 28/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 101s 259ms/step - accuracy: 0.3944 - loss: 1.6978 - val_accuracy: 0.3902 - val_loss: 1.6783
# Epoch 29/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 142s 260ms/step - accuracy: 0.3911 - loss: 1.7014 - val_accuracy: 0.4117 - val_loss: 1.6437
# Epoch 30/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 140s 256ms/step - accuracy: 0.3860 - loss: 1.7141 - val_accuracy: 0.4095 - val_loss: 1.6460
# Epoch 31/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 142s 257ms/step - accuracy: 0.3923 - loss: 1.6985 - val_accuracy: 0.3981 - val_loss: 1.6848
# Epoch 32/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 142s 257ms/step - accuracy: 0.3954 - loss: 1.6901 - val_accuracy: 0.3863 - val_loss: 1.6882
# Epoch 33/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 101s 258ms/step - accuracy: 0.3914 - loss: 1.6995 - val_accuracy: 0.4128 - val_loss: 1.6358
# Epoch 34/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 101s 258ms/step - accuracy: 0.3980 - loss: 1.6921 - val_accuracy: 0.4010 - val_loss: 1.6499
# Epoch 35/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 142s 258ms/step - accuracy: 0.3971 - loss: 1.6989 - val_accuracy: 0.4280 - val_loss: 1.6030
# Epoch 36/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 102s 260ms/step - accuracy: 0.3977 - loss: 1.6880 - val_accuracy: 0.4222 - val_loss: 1.6155
# Epoch 37/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 142s 259ms/step - accuracy: 0.3969 - loss: 1.6881 - val_accuracy: 0.4293 - val_loss: 1.6029
# Epoch 38/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 102s 260ms/step - accuracy: 0.3988 - loss: 1.6821 - val_accuracy: 0.4295 - val_loss: 1.6106
# Epoch 39/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 102s 260ms/step - accuracy: 0.3997 - loss: 1.6743 - val_accuracy: 0.4265 - val_loss: 1.6046
# Epoch 40/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 142s 262ms/step - accuracy: 0.4005 - loss: 1.6764 - val_accuracy: 0.4194 - val_loss: 1.6450
# Epoch 41/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 103s 264ms/step - accuracy: 0.4009 - loss: 1.6761 - val_accuracy: 0.4366 - val_loss: 1.5854
# Epoch 42/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 102s 261ms/step - accuracy: 0.4090 - loss: 1.6628 - val_accuracy: 0.4339 - val_loss: 1.6023
# Epoch 43/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 101s 258ms/step - accuracy: 0.4042 - loss: 1.6717 - val_accuracy: 0.4177 - val_loss: 1.6255
# Epoch 44/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 142s 258ms/step - accuracy: 0.4054 - loss: 1.6640 - val_accuracy: 0.4251 - val_loss: 1.6108
# Epoch 45/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 143s 260ms/step - accuracy: 0.4032 - loss: 1.6714 - val_accuracy: 0.4053 - val_loss: 1.6839
# Epoch 46/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 101s 258ms/step - accuracy: 0.4024 - loss: 1.6770 - val_accuracy: 0.4202 - val_loss: 1.6017
# Epoch 47/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 102s 260ms/step - accuracy: 0.4050 - loss: 1.6734 - val_accuracy: 0.4189 - val_loss: 1.6395
# Epoch 48/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 102s 261ms/step - accuracy: 0.4098 - loss: 1.6574 - val_accuracy: 0.4105 - val_loss: 1.6513
# Epoch 49/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 102s 261ms/step - accuracy: 0.4055 - loss: 1.6702 - val_accuracy: 0.4250 - val_loss: 1.6059
# Epoch 50/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 101s 259ms/step - accuracy: 0.4111 - loss: 1.6517 - val_accuracy: 0.4318 - val_loss: 1.5923
# Total training time 5826.036165475845 s

# %%
_, axes = plt.subplots(2, 2, figsize = (10, 10))
labels = ["Training loss", "Validation loss", "Training accuracy", "Validation Accuracy"]
est = ["loss", "val_loss", "accuracy", "val_accuracy"]

for i, ax in enumerate(axes.flat):
    ax.plot(history.history[est[i]], label = labels[i])
    ax.set_title(labels[i])
    ax.legend()
    
plt.show()
